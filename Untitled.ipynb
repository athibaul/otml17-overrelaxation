# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 50; M = 50
p1 = np.random.randn(N,2).dot(np.diag([2,0.5]))
p2 = np.random.randn(M,2)
c = np.zeros((N,M))

for i in range(N):
    for j in range(M):
        c[i][j] = np.linalg.norm(p1[i,:]-p2[j,:])
        
epsilon = 1e-2
K = np.exp(-c/epsilon)
print(np.shape(K))
K_ = np.transpose(K)

mu = np.random.rand(N)
mu = mu/np.sum(mu)
nu = np.random.rand(M)
nu = nu/np.sum(nu)
# Out:
# (50, 50)

# %%
a = np.ones(N); b = np.ones(M)
err = []
for k in range(100):
    a = mu / K.dot(b)
    b = nu / K_.dot(a)

gamma = np.diag(a).dot(K.dot(np.diag(b)))
print(gamma)
# Out:
# [[  9.60755631e-32   1.04583535e-82   6.94195113e-41 ...,   1.39654548e-27
#     5.00160234e-40   1.33478666e-58]
#  [  9.46284374e-22   2.06918398e-48   4.10671674e-32 ...,   2.55348165e-04
#     1.59830005e-12   2.10530024e-24]
#  [  4.77434015e-23   3.20706480e-31   1.09047202e-29 ...,   1.58189987e-15
#     4.40746281e-05   1.84865204e-11]
#  ...,
#  [  4.23341623e-84   6.39032928e-98   7.49084214e-95 ...,   1.07775442e-36
#     7.78862352e-80   1.88233244e-77]
#  [  1.67150282e-73   1.32166241e-08   3.68919230e-78 ...,   5.82834237e-25
#     3.66530335e-56   2.51862253e-22]
#  [  7.70976673e-32   2.94881588e-35   5.70455675e-40 ...,   1.17062688e-06
#     1.28502942e-14   1.15297370e-11]]

# %%
fig=plt.figure(figsize=(12,10))


gamma_n = gamma*np.sqrt(N*M)*5
for i in range(N):
    for j in range(M):
        plt.plot([p1[i,0],p2[j,0]],[p1[i,1],p2[j,1]],color='purple',linewidth=gamma_n[i][j])
        
plt.scatter(p1[:,0],p1[:,1],s=mu*500*N/2,color='red')
plt.scatter(p2[:,0],p2[:,1],s=nu*500*N/2,color='blue')
plt.axis('equal')
plt.axis('off')
plt.show()

# %%
N = 100
xx = np.linspace(0,1,N)
mu = 1 + (0.5<xx)*(0.6>xx)
mu = mu/np.sum(mu)
#nu = np.exp(-(xx-0.2)**2*1000) + np.exp(-(xx-0.7)**2*150)
nu = (0.0<=xx)
nu = nu/np.sum(nu)

xxx,yyy = np.meshgrid(xx,xx)
c = np.abs(xxx-yyy)
epsilon = 1e-3
K = np.exp(-c/epsilon)
K_ = np.transpose(K)
print(K)
# Out:
# [[  1.00000000e+00   4.10380817e-05   1.68412415e-09 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  4.10380817e-05   1.00000000e+00   4.10380817e-05 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.68412415e-09   4.10380817e-05   1.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   1.00000000e+00
#     4.10380817e-05   1.68412415e-09]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   4.10380817e-05
#     1.00000000e+00   4.10380817e-05]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   1.68412415e-09
#     4.10380817e-05   1.00000000e+00]]

# %%
plt.plot(mu)
plt.plot(nu)
plt.show()

# %%
a = np.ones(N); b = np.ones(N)
errs_init = []
err = 1
while err>1e-12:
    a = mu / K.dot(b)
    b = nu / K_.dot(a)
    err = np.linalg.norm(mu - a * (K.dot(b))) + np.linalg.norm(nu - b * (K_.dot(a)))
    errs_init.append(err)
    
a_true = a; b_true = b;
aibj_true = np.outer(a,b)
print(aibj_true)
gamma_true = np.diag(a).dot(K.dot(np.diag(b)))

def F(aibj):
    return np.sum(K * (aibj_true * np.log(aibj_true / aibj) - aibj_true + aibj), axis=None)

plt.semilogy(errs_init)
eta = (errs_init[-2]-errs_init[-1])/errs_init[-1]
theta_0 = 2/(1+np.sqrt(eta))
print("eta =",eta,"theta0 =",theta_0)
plt.show()
# Out:
# [[  9.09090892e-03   4.10380726e-06   1.01047423e-09 ...,   4.73104314e-57
#     1.92140370e-53   4.25636609e-50]
#  [  1.84603144e+01   8.33333312e-03   2.05190395e-06 ...,   9.60702001e-54
#     3.90166888e-50   8.64312435e-47]
#  [  6.92051966e+04   3.12405273e+01   7.69230758e-03 ...,   3.60154055e-50
#     1.46268236e-46   3.24018923e-43]
#  ...,
#  [  1.47811097e+52   6.67247090e+48   1.64295237e+45 ...,   7.69230758e-03
#     3.12405273e+01   6.92051967e+04]
#  [  3.94282431e+48   1.77986505e+45   4.38253467e+41 ...,   2.05190395e-06
#     8.33333312e-03   1.84603144e+01]
#  [  1.94167098e+45   8.76506797e+41   2.15820937e+38 ...,   1.01047423e-09
#     4.10380726e-06   9.09090892e-03]]
# eta = 0.00453043209603 theta0 = 1.87387248289

# %%
def phi(theta,x):
    return x*(1-x**(-theta)) - theta*np.log(x)

thetas = np.linspace(1,theta_0,5000)[::-1]
def Theta(x):
    positives = (phi(thetas,x) > 0)
    i = np.argmax(positives)
    if positives[i]:
        return thetas[i]
    else:
        return 1

# %%
a = np.ones(N); b = np.ones(N)
errs = []
ks = [k for k in range(500)]

a_ = np.ones(N); b_ = np.ones(N)
errs_ = []
theta_a = []; theta_b = []
for k in ks:
    a = mu / K.dot(b)
    b = nu / K_.dot(a)
    #err = np.linalg.norm(mu - a * (K.dot(b))) + np.linalg.norm(nu - b * (K_.dot(a)))
    err = F(np.outer(a,b))
    errs.append(err)
    
    a_ratio = mu / (a_ * K.dot(b_))
    theta = Theta(1/np.max(a_ratio))
    theta_a.append(theta)
    a_ = a_*(a_ratio**theta)
    b_ratio = nu / (b_ * K_.dot(a_))
    theta = Theta(1/np.max(b_ratio))
    theta_b.append(theta)
    b_ = b_*(b_ratio**theta)
    #err = np.linalg.norm(mu - a_ * (K.dot(b_))) + np.linalg.norm(nu - b_ * (K_.dot(a_)))
    err = F(np.outer(a_,b_))
    errs_.append(err)

theta_a = np.array(theta_a); theta_b = np.array(theta_b)
#print(np.array(errs))
gamma = np.diag(a).dot(K.dot(np.diag(b)))


plt.style.use(['ggplot','seaborn-poster'])
#plt.imshow(gamma)
fig,ax1 = plt.subplots(figsize=(6,0.618*6))
#ax1.semilogy(ks,errs,label='Sinkhorn')
ax1.semilogy(ks,errs_,label='Overrelaxed')
ax2 = ax1.twinx()
ax2.plot([],[])
ax2.plot(ks,theta_a,'--',label='$\\theta_1$')
ax2.plot(ks,theta_b,'--',label='$\\theta_2$')
ax2.grid(False)
plt.legend(loc='lower left')
plt.show()

# %%
plt.style.available
# Out:
# ['seaborn-white',
#  'seaborn-muted',
#  'seaborn-pastel',
#  'seaborn-colorblind',
#  'seaborn-ticks',
#  'dark_background',
#  'grayscale',
#  'fivethirtyeight',
#  'seaborn-talk',
#  'seaborn-deep',
#  'seaborn-notebook',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-poster',
#  'seaborn-bright',
#  'seaborn-dark',
#  'seaborn-whitegrid',
#  'classic',
#  'bmh',
#  'ggplot',
#  'seaborn-paper']

# %%
import matplotlib
matplotlib.__version__
# Out:
# '1.5.1'

# %%
help()
# Out:
# Welcome to Python 3.5's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at http://docs.python.org/3.5/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> version
# No Python documentation found for 'version'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# help> python
# No Python documentation found for 'python'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# help> exit
# No Python documentation found for 'exit'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.
